# %%
import pandas as pd

dataframe = pd.read_csv('../csv/empresa_ativa.csv', low_memory=False, index_col=0)
dataframe
# Out:
#                   cnpj                                 razao_social  \
# 0       50669717000107                                  ECOSAT LTDA
# 1       50669717000107                                  ECOSAT LTDA
# 2       50669717000107                                  ECOSAT LTDA
# 3       50669717000107                                  ECOSAT LTDA
# 4       12859211000163     ASSOCIACAO DE MORADORES DE VILA AEROMOCA
# ...                ...                                          ...
# 364096  40561683000170           DOIS IRMAOS ARENA DE ESPORTES LTDA
# 364097  40561683000170           DOIS IRMAOS ARENA DE ESPORTES LTDA
# 364098  40561683000170           DOIS IRMAOS ARENA DE ESPORTES LTDA
# 364099  27597663000191  COLISEU VIGILANCIA E SEGURANCA PRIVADA LTDA
# 364100  40811846000126                      GRUPO UNIAO COMUNITARIA
#
#                                  nome_fantasia  cod_logradouro  \
# 0                                       ECOSAT            9342
# ...
