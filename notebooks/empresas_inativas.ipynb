# %%
import pandas as pd

dataframe = pd.read_csv('../csv/empresa_inativa.csv', low_memory=False, index_col=0)
dataframe
# Out:
#                   cnpj                                       razao_social  \
# 0       03561119000121                            ROTENO CONSTRUCOES LTDA
# 1       03561119000121                            ROTENO CONSTRUCOES LTDA
# 2       03561119000121                            ROTENO CONSTRUCOES LTDA
# 3       00388321000105                      CAMADA OLISI CONSTRUCOES LTDA
# 4       00388321000105                      CAMADA OLISI CONSTRUCOES LTDA
# ...                ...                                                ...
# 389768  35617117000101               EPEC ESTUDOS PESQUISAS E CONSULTORIA
# 389769  07265388000100  LABORATORIO DE ANALISES AMB PRODUTOS ALIMENTIC...
# 389770  07265388000100  LABORATORIO DE ANALISES AMB PRODUTOS ALIMENTIC...
# 389771  17540884000170  3N COMERCIO DE INSTRUMENTOS LABORATORIAIS LTDA ME
# 389772  40869695000167    TRANSPORTE COMERCIO E REPRESENTACOES J I  LTDA.
#
#                                             nome_fantasia  cod_logradouro  \
# ...
